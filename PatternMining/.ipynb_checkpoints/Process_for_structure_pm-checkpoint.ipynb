# %% [markdown]
# <a href="https://colab.research.google.com/github/Marine27/TER/blob/master/PatternMining/Process_for_structure_pm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mise en forme des donnees pour le *Pattern Mining*

# %% [markdown]
# ### Imports

# %%
import pandas as pd  
import numpy as np
import warnings

# %% [markdown]
# ### Recuperation et preparation des donnnees

# %%
#Chargement du jeu de donnees
data_child = pd.read_csv('/Users/marine/Desktop/Projet_TER/TER/data/data_madeleine_final.csv',
                           sep = '\t',
                           encoding = 'utf-8',
                           index_col = False)

# Supression de la colonne qui duplique l'index
data_child = data_child.drop(columns = 'Unnamed: 0') 

# Recuperation de la partie phonetique des intervention de l'enfant
data_child = data_child.where(data_child['type']=='pho').dropna(subset=['type'])

# Conservation des deux colonnes avec des informations pertinantes 
data_child = data_child[['age','contenu']]

# Creer un indexage a partir de cet ordre
data_child['index']=[ i for i in range(len(data_child))]
data_child= data_child.set_index('index')

# Creation d'un numpy utile par la suite pour les boucles
ages = data_child.age.unique()

# Indexage par l'age de l'enfant
age = data_child['age']

l=[i for i in range(len(age))]
k=[age.values]
k.append(l)
tuples = list(zip(*k))

index = pd.MultiIndex.from_tuples(tuples, names=['age', 'index'])
data_child.set_index(index,inplace=True)

# Supression de la colonne age car present en index
data_child=data_child[['contenu']]

data_child.head()
# Out:
#               contenu
# age     index
# 1_00_05 0          eː
#         1          bɛ
#         2        vœga
#         3       gatœ̃
#         4        kaka

# %% [markdown]
# ### Demarches pour la division de chaque enregistrement en 4 parties

# %%
# Sépare en mots au lieu de phrases
mots = {}
for i in list(ages):
    # recupere toutes les phrases a la i eme date
    phrases = data_child['contenu'].loc[i].values
    # creer une variable texte avec toutes les phrases
    phrase = ' '.join(phrases)
    # sépare en mot
    mots[i] = phrase.split()
    
# se parcourt avec un age en parametre
#mots["1_00_05"]

# %%
# Sépare en 4 "enfants" chaque enregistrement
enregistrement = {}
sizes = []
for i in list(ages):
    # recupere tout les mots a la i eme date
    #data = data_child['contenu'].loc[i].values
    data = mots[i]
    # separe les mots en 4 groupes ( 3 goupes de meme dim et le dernier avec le reste)
    if len(data)<4:
        warnings.warn("\nAttention un l'enregistrement "+ i + " contient moins de 4 mots")
    s = len(data)//4
    sizes.append(s)
    enfant1 = data[:s]
    enfant2 = data[s:2*s]
    enfant3 = data[2*s:3*s]
    enfant4 = data[3*s:]
    # creer une variable texte de chaque goupe
    #enfant1 = ' '.join(enfant1)
    #enfant2 = ' '.join(enfant2)
    #enfant3 = ' '.join(enfant3)
    #enfant4 = ' '.join(enfant4)
    
    enfant1 = tuple(enfant1)
    enfant2 = tuple(enfant2)
    enfant3 = tuple(enfant3)
    enfant4 = tuple(enfant4)
    
    # sépare en 4 enfants
    enregistrement[i] = [enfant1, enfant2, enfant3, enfant4]
    
# se parcourt avec un age en parametre
#enregistrement["1_00_05"]
# Out:
# /Users/marine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning:
# Attention un l'enregistrement 6_11_27 contient moins de 4 mots
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Pour avoir une idée du nombre de mots par enregistrement après répartition
pd.DataFrame(sizes[:-1]).describe().T
# Out:
#    count        mean         std   min     25%    50%     75%     max
# 0   34.0  395.588235  285.178744  15.0  126.75  364.0  646.25  1101.0

# %%
# Crée une DataFrame de toutes les donnees
tab_4groupes = []
#sizes = []
for i in list(ages):
    t = enregistrement[i]
    #s = len(t)
    tab_4groupes.append(t)
    #sizes.append(s)
    
tab_madeleine = pd.DataFrame(tab_4groupes)

etiquettes = ["madeleine_enfant1",
              "madeleine_enfant2", 
              "madeleine_enfant3", 
              "madeleine_enfant4"]

tab_madeleine.columns = etiquettes

tab_madeleine.head()
# tab_madeleine.loc[1] recherche par numero de l'enregistrement
# tab_madeleine[1] recherche par numero de l'enfant
# Out:
#                                    madeleine_enfant1  \
# 0  (eː, bɛ, vœga, gatœ̃, kaka, dœjøkɛka, m, taka,...
# 1  (ja, aljɛla, jaka, meja, agø, ga, beːja, ʃa, o...
# 2  (je, ʃidɔm, øʃi, alapa, ʃː, ʃ, a, ʃa, øː, aaː,...
# 3  (evøpuʃa, gegedɔ̃, dɔ, ty, hɛsys, ejə, ʃa, gøt...
# 4  (i, lɛ, vwa, a, aː, ti, vwa, aː, ty, pø, t, as...
#
#                                    madeleine_enfant2  \
# 0  (gla, ga, ga, gøga, gøga, ga, gaga, a, deda, œ...
# 1  (ʃa, ʃa, ʃa, ʃa, ʃa, ʃa, ʃa, ʃa, ʃa, aja, ja, ...
# 2  (bɛ, y, øː, ʃ, mememebuja, eaa, iɲa, ia, ʃɛ̃, ...
# 3  (mama, mama, bekaliʃaʃa, øtatɛ, mama, løʃa, pe...
# 4  (wikɔ, ejdøwa, ɛʃa, pøpa, ɛøgødididitetɛe, bøb...
#
#                                    madeleine_enfant3  \
# 0  (gaga, gaga, gagaga, ga, mœmœmœmœ, ala, adla, ...
# 1  (ʃa, ejaː, edjadjajaaa, edahahaoga, u, ajne, e...
# 2  (ʃa, ʒy, aːaːɛ, ɛɛ, sə, wauːua, a, χ, wa, waa,...
# 3  (ʃa, ʃa, ʃa, ʃa, ʃa, ʃa, ʃa, ʃːa, səba, ʃa, ʃa...
# 4  (wœ, wa, wawa, pwapwa, awœ, œœ, ba, m, jeje, e...
#
#                                    madeleine_enfant4
# 0  (œmøː, œmøː, gaga, gagaga, daɥy, aga, œm, œm, ...
# 1  (ada, aja, gɛʒeʒa, ajəda, dedaː, da, ega, ja, ...
# 2  (bidun, bida, bjɛtna, bebøː, dakula, daguba, m...
# 3  (lelɛ, lala, lala, uu, iː, jejejejejee, eː, mː...
# 4  (jije, ini, œː, i, ʃi, uba, veve, tilele, nine...

# %% [markdown]
# ### Addaptation de la structure

# %%
# transactions = (('a', 'b', 'c'), ('b'), ('a'), ('a', 'c', 'd'), ('b', 'c'), ('b', 'c'))
# doit etre de cette forme:
# madeleine_enfant1 = transactions
# un enregistrement = ('a', 'b', 'c')
# un mot = 'a'

# %%
madeleine_enfant1 = tuple(tab_madeleine["madeleine_enfant1"][:-1])
madeleine_enfant2 = tuple(tab_madeleine["madeleine_enfant2"][:-1])
madeleine_enfant3 = tuple(tab_madeleine["madeleine_enfant3"][:-1])
madeleine_enfant4 = tuple(tab_madeleine["madeleine_enfant4"][:])

# %%
print(type(madeleine_enfant1))
#print(madeleine_enfant1)
# Out:
# <class 'tuple'>

# %% [markdown]
# ### PATTERN MINING

# %%
from pymining import itemmining
from pymining import assocrules

from pymining import seqmining

# %%
min_supp = 20
relim_input = itemmining.get_relim_input(madeleine_enfant1)
item_sets = itemmining.relim(relim_input, min_support=min_supp) # min_support= nbr au pif < lignes
item_sets
# Out:
# {frozenset({'de'}): 20,
#  frozenset({'de', 'mwa'}): 20,
#  frozenset({'de', 'mwa', 'pa'}): 20,
#  frozenset({'de', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'de', 'la', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'a', 'de', 'la', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'a', 'de', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'de', 'la', 'mwa', 'pa'}): 20,
#  frozenset({'a', 'de', 'la', 'mwa', 'pa'}): 20,
#  frozenset({'a', 'de', 'mwa', 'pa'}): 20,
#  frozenset({'de', 'mwa', 'sa'}): 20,
#  frozenset({'de', 'la', 'mwa', 'sa'}): 20,
#  frozenset({'a', 'de', 'la', 'mwa', 'sa'}): 20,
#  frozenset({'a', 'de', 'mwa', 'sa'}): 20,
#  frozenset({'de', 'la', 'mwa'}): 20,
#  frozenset({'a', 'de', 'la', 'mwa'}): 20,
#  frozenset({'a', 'de', 'mwa'}): 20,
#  frozenset({'de', 'pa'}): 20,
#  frozenset({'de', 'pa', 'sa'}): 20,
#  frozenset({'de', 'la', 'pa', 'sa'}): 20,
#  frozenset({'a', 'de', 'la', 'pa', 'sa'}): 20,
#  frozenset({'a', 'de', 'pa', 'sa'}): 20,
#  frozenset({'de', 'la', 'pa'}): 20,
#  frozenset({'a', 'de', 'la', 'pa'}): 20,
#  frozenset({'a', 'de', 'pa'}): 20,
#  frozenset({'de', 'sa'}): 20,
#  frozenset({'de', 'la', 'sa'}): 20,
#  frozenset({'a', 'de', 'la', 'sa'}): 20,
#  frozenset({'a', 'de', 'sa'}): 20,
#  frozenset({'de', 'la'}): 20,
#  frozenset({'a', 'de', 'la'}): 20,
#  frozenset({'a', 'de'}): 20,
#  frozenset({'də'}): 20,
#  frozenset({'də', 'sa'}): 20,
#  frozenset({'də', 'la', 'sa'}): 20,
#  frozenset({'də', 'e', 'la', 'sa'}): 20,
#  frozenset({'a', 'də', 'e', 'la', 'sa'}): 20,
#  frozenset({'a', 'də', 'la', 'sa'}): 20,
#  frozenset({'də', 'e', 'sa'}): 20,
#  frozenset({'a', 'də', 'e', 'sa'}): 20,
#  frozenset({'a', 'də', 'sa'}): 20,
#  frozenset({'də', 'la'}): 20,
#  frozenset({'də', 'e', 'la'}): 20,
#  frozenset({'a', 'də', 'e', 'la'}): 20,
#  frozenset({'a', 'də', 'la'}): 20,
#  frozenset({'də', 'e'}): 20,
#  frozenset({'a', 'də', 'e'}): 20,
#  frozenset({'a', 'də'}): 20,
#  frozenset({'fɛ'}): 20,
#  frozenset({'fɛ', 'sa'}): 20,
#  frozenset({'fɛ', 'la', 'sa'}): 20,
#  frozenset({'a', 'fɛ', 'la', 'sa'}): 20,
#  frozenset({'a', 'fɛ', 'sa'}): 20,
#  frozenset({'fɛ', 'la'}): 20,
#  frozenset({'a', 'fɛ', 'la'}): 20,
#  frozenset({'a', 'fɛ'}): 20,
#  frozenset({'nɔ̃'}): 20,
#  frozenset({'nɔ̃', 'pa'}): 20,
#  frozenset({'nɔ̃', 'pa', 'sa'}): 20,
#  frozenset({'la', 'nɔ̃', 'pa', 'sa'}): 20,
#  frozenset({'a', 'la', 'nɔ̃', 'pa', 'sa'}): 20,
#  frozenset({'a', 'nɔ̃', 'pa', 'sa'}): 20,
#  frozenset({'la', 'nɔ̃', 'pa'}): 20,
#  frozenset({'a', 'la', 'nɔ̃', 'pa'}): 20,
#  frozenset({'a', 'nɔ̃', 'pa'}): 20,
#  frozenset({'nɔ̃', 'sa'}): 20,
#  frozenset({'la', 'nɔ̃', 'sa'}): 20,
#  frozenset({'a', 'la', 'nɔ̃', 'sa'}): 20,
#  frozenset({'a', 'nɔ̃', 'sa'}): 20,
#  frozenset({'la', 'nɔ̃'}): 20,
#  frozenset({'a', 'la', 'nɔ̃'}): 20,
#  frozenset({'a', 'nɔ̃'}): 20,
#  frozenset({'ə'}): 20,
#  frozenset({'ʒ'}): 20,
#  frozenset({'mwa', 'ʒ'}): 20,
#  frozenset({'a', 'mwa', 'ʒ'}): 20,
#  frozenset({'a', 'ʒ'}): 20,
#  frozenset({'dɑ̃'}): 21,
#  frozenset({'dɑ̃', 'pa'}): 20,
#  frozenset({'dɑ̃', 'pa', 'sa'}): 20,
#  frozenset({'dɑ̃', 'la', 'pa', 'sa'}): 20,
#  frozenset({'a', 'dɑ̃', 'la', 'pa', 'sa'}): 20,
#  frozenset({'a', 'dɑ̃', 'pa', 'sa'}): 20,
#  frozenset({'dɑ̃', 'la', 'pa'}): 20,
#  frozenset({'a', 'dɑ̃', 'la', 'pa'}): 20,
#  frozenset({'a', 'dɑ̃', 'pa'}): 20,
#  frozenset({'dɑ̃', 'sa'}): 21,
#  frozenset({'dɑ̃', 'la', 'sa'}): 21,
#  frozenset({'dɑ̃', 'e', 'la', 'sa'}): 20,
#  frozenset({'a', 'dɑ̃', 'e', 'la', 'sa'}): 20,
#  frozenset({'a', 'dɑ̃', 'la', 'sa'}): 21,
#  frozenset({'dɑ̃', 'e', 'sa'}): 20,
#  frozenset({'a', 'dɑ̃', 'e', 'sa'}): 20,
#  frozenset({'a', 'dɑ̃', 'sa'}): 21,
#  frozenset({'dɑ̃', 'la'}): 21,
#  frozenset({'dɑ̃', 'e', 'la'}): 20,
#  frozenset({'a', 'dɑ̃', 'e', 'la'}): 20,
#  frozenset({'a', 'dɑ̃', 'la'}): 21,
#  frozenset({'dɑ̃', 'e'}): 20,
#  frozenset({'a', 'dɑ̃', 'e'}): 20,
#  frozenset({'a', 'dɑ̃'}): 21,
#  frozenset({'il'}): 21,
#  frozenset({'il', 'le'}): 20,
#  frozenset({'il', 'le', 'sa'}): 20,
#  frozenset({'il', 'la', 'le', 'sa'}): 20,
#  frozenset({'a', 'il', 'la', 'le', 'sa'}): 20,
#  frozenset({'a', 'il', 'le', 'sa'}): 20,
#  frozenset({'il', 'la', 'le'}): 20,
#  frozenset({'a', 'il', 'la', 'le'}): 20,
#  frozenset({'a', 'il', 'le'}): 20,
#  frozenset({'il', 'sa'}): 20,
#  frozenset({'il', 'la', 'sa'}): 20,
#  frozenset({'a', 'il', 'la', 'sa'}): 20,
#  frozenset({'a', 'il', 'sa'}): 20,
#  frozenset({'il', 'la'}): 21,
#  frozenset({'e', 'il', 'la'}): 20,
#  frozenset({'a', 'e', 'il', 'la'}): 20,
#  frozenset({'a', 'il', 'la'}): 21,
#  frozenset({'e', 'il'}): 20,
#  frozenset({'a', 'e', 'il'}): 20,
#  frozenset({'a', 'il'}): 21,
#  frozenset({'va'}): 21,
#  frozenset({'va', 'wi'}): 20,
#  frozenset({'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'sa', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'va', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'va', 'wi'}): 20,
#  frozenset({'mwa', 'pa', 'va', 'wi'}): 20,
#  frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'va', 'wi'}): 20,
#  frozenset({'mwa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'va', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'va', 'wi'}): 20,
#  frozenset({'pa', 'va', 'wi'}): 20,
#  frozenset({'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'pa', 'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'pa', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'pa', 'va', 'wi'}): 20,
#  frozenset({'a', 'pa', 'va', 'wi'}): 20,
#  frozenset({'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'sa', 'va', 'wi'}): 20,
#  frozenset({'a', 'sa', 'va', 'wi'}): 20,
#  frozenset({'la', 'va', 'wi'}): 20,
#  frozenset({'a', 'la', 'va', 'wi'}): 20,
#  frozenset({'a', 'va', 'wi'}): 20,
#  frozenset({'va', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'va', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'va', 'ɔ̃'}): 20,
#  frozenset({'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'va', 'ɔ̃'}): 20,
#  frozenset({'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'sa', 'va', 'ɔ̃'}): 20,
#  frozenset({'la', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'va', 'ɔ̃'}): 20,
#  frozenset({'a', 'va', 'ɔ̃'}): 20,
#  frozenset({'i', 'va'}): 20,
#  frozenset({'i', 'sa', 'va'}): 20,
#  frozenset({'i', 'la', 'sa', 'va'}): 20,
#  frozenset({'a', 'i', 'la', 'sa', 'va'}): 20,
#  frozenset({'a', 'i', 'sa', 'va'}): 20,
#  frozenset({'i', 'la', 'va'}): 20,
#  frozenset({'a', 'i', 'la', 'va'}): 20,
#  frozenset({'a', 'i', 'va'}): 20,
#  frozenset({'mwa', 'va'}): 20,
#  frozenset({'mwa', 'pa', 'va'}): 20,
#  frozenset({'mwa', 'pa', 'sa', 'va'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'sa', 'va'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa', 'va'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'va'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'va'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'va'}): 20,
#  frozenset({'mwa', 'sa', 'va'}): 20,
#  frozenset({'la', 'mwa', 'sa', 'va'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa', 'va'}): 20,
#  frozenset({'a', 'mwa', 'sa', 'va'}): 20,
#  frozenset({'la', 'mwa', 'va'}): 20,
#  frozenset({'a', 'la', 'mwa', 'va'}): 20,
#  frozenset({'a', 'mwa', 'va'}): 20,
#  frozenset({'pa', 'va'}): 20,
#  frozenset({'pa', 'sa', 'va'}): 20,
#  frozenset({'la', 'pa', 'sa', 'va'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'va'}): 20,
#  frozenset({'a', 'pa', 'sa', 'va'}): 20,
#  frozenset({'la', 'pa', 'va'}): 20,
#  frozenset({'a', 'la', 'pa', 'va'}): 20,
#  frozenset({'a', 'pa', 'va'}): 20,
#  frozenset({'sa', 'va'}): 21,
#  frozenset({'la', 'sa', 'va'}): 21,
#  frozenset({'e', 'la', 'sa', 'va'}): 20,
#  frozenset({'a', 'e', 'la', 'sa', 'va'}): 20,
#  frozenset({'a', 'la', 'sa', 'va'}): 21,
#  frozenset({'e', 'sa', 'va'}): 20,
#  frozenset({'a', 'e', 'sa', 'va'}): 20,
#  frozenset({'a', 'sa', 'va'}): 21,
#  frozenset({'la', 'va'}): 21,
#  frozenset({'e', 'la', 'va'}): 20,
#  frozenset({'a', 'e', 'la', 'va'}): 20,
#  frozenset({'a', 'la', 'va'}): 21,
#  frozenset({'e', 'va'}): 20,
#  frozenset({'a', 'e', 'va'}): 20,
#  frozenset({'a', 'va'}): 21,
#  frozenset({'yn'}): 21,
#  frozenset({'wi', 'yn'}): 20,
#  frozenset({'mwa', 'wi', 'yn'}): 20,
#  frozenset({'la', 'mwa', 'wi', 'yn'}): 20,
#  frozenset({'a', 'la', 'mwa', 'wi', 'yn'}): 20,
#  frozenset({'a', 'mwa', 'wi', 'yn'}): 20,
#  frozenset({'la', 'wi', 'yn'}): 20,
#  frozenset({'a', 'la', 'wi', 'yn'}): 20,
#  frozenset({'a', 'wi', 'yn'}): 20,
#  frozenset({'yn', 'ɔ̃'}): 20,
#  frozenset({'pa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'pa', 'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'la', 'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'sa', 'yn', 'ɔ̃'}): 20,
#  frozenset({'la', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'yn', 'ɔ̃'}): 20,
#  frozenset({'a', 'yn', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'yn'}): 20,
#  frozenset({'la', 'mwa', 'yn'}): 20,
#  frozenset({'a', 'la', 'mwa', 'yn'}): 20,
#  frozenset({'a', 'mwa', 'yn'}): 20,
#  frozenset({'pa', 'yn'}): 20,
#  frozenset({'pa', 'sa', 'yn'}): 20,
#  frozenset({'la', 'pa', 'sa', 'yn'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'yn'}): 20,
#  frozenset({'a', 'pa', 'sa', 'yn'}): 20,
#  frozenset({'la', 'pa', 'yn'}): 20,
#  frozenset({'a', 'la', 'pa', 'yn'}): 20,
#  frozenset({'a', 'pa', 'yn'}): 20,
#  frozenset({'sa', 'yn'}): 20,
#  frozenset({'la', 'sa', 'yn'}): 20,
#  frozenset({'a', 'la', 'sa', 'yn'}): 20,
#  frozenset({'a', 'sa', 'yn'}): 20,
#  frozenset({'la', 'yn'}): 21,
#  frozenset({'e', 'la', 'yn'}): 20,
#  frozenset({'a', 'e', 'la', 'yn'}): 20,
#  frozenset({'a', 'la', 'yn'}): 21,
#  frozenset({'e', 'yn'}): 20,
#  frozenset({'a', 'e', 'yn'}): 20,
#  frozenset({'a', 'yn'}): 21,
#  frozenset({'ɑ̃'}): 21,
#  frozenset({'la', 'ɑ̃'}): 20,
#  frozenset({'e', 'la', 'ɑ̃'}): 20,
#  frozenset({'a', 'e', 'la', 'ɑ̃'}): 20,
#  frozenset({'a', 'la', 'ɑ̃'}): 20,
#  frozenset({'e', 'ɑ̃'}): 21,
#  frozenset({'a', 'e', 'ɑ̃'}): 21,
#  frozenset({'a', 'ɑ̃'}): 21,
#  frozenset({'X'}): 22,
#  frozenset({'X', 'la'}): 20,
#  frozenset({'X', 'a', 'la'}): 20,
#  frozenset({'X', 'e'}): 20,
#  frozenset({'X', 'a'}): 21,
#  frozenset({'o'}): 22,
#  frozenset({'e', 'o'}): 20,
#  frozenset({'a', 'o'}): 21,
#  frozenset({'se'}): 22,
#  frozenset({'le', 'se'}): 21,
#  frozenset({'i', 'le', 'se'}): 20,
#  frozenset({'i', 'le', 'sa', 'se'}): 20,
#  frozenset({'i', 'la', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'i', 'le', 'sa', 'se'}): 20,
#  frozenset({'i', 'la', 'le', 'se'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'se'}): 20,
#  frozenset({'a', 'i', 'le', 'se'}): 20,
#  frozenset({'l', 'le', 'se'}): 20,
#  frozenset({'l', 'le', 'sa', 'se'}): 20,
#  frozenset({'l', 'la', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'l', 'la', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'l', 'le', 'sa', 'se'}): 20,
#  frozenset({'l', 'la', 'le', 'se'}): 20,
#  frozenset({'a', 'l', 'la', 'le', 'se'}): 20,
#  frozenset({'a', 'l', 'le', 'se'}): 20,
#  frozenset({'le', 'pa', 'se'}): 20,
#  frozenset({'le', 'pa', 'sa', 'se'}): 20,
#  frozenset({'la', 'le', 'pa', 'sa', 'se'}): 20,
#  frozenset({'a', 'la', 'le', 'pa', 'sa', 'se'}): 20,
#  frozenset({'a', 'le', 'pa', 'sa', 'se'}): 20,
#  frozenset({'la', 'le', 'pa', 'se'}): 20,
#  frozenset({'a', 'la', 'le', 'pa', 'se'}): 20,
#  frozenset({'a', 'le', 'pa', 'se'}): 20,
#  frozenset({'le', 'sa', 'se'}): 21,
#  frozenset({'la', 'le', 'sa', 'se'}): 21,
#  frozenset({'e', 'la', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'e', 'la', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'la', 'le', 'sa', 'se'}): 21,
#  frozenset({'e', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'e', 'le', 'sa', 'se'}): 20,
#  frozenset({'a', 'le', 'sa', 'se'}): 21,
#  frozenset({'la', 'le', 'se'}): 21,
#  frozenset({'e', 'la', 'le', 'se'}): 20,
#  frozenset({'a', 'e', 'la', 'le', 'se'}): 20,
#  frozenset({'a', 'la', 'le', 'se'}): 21,
#  frozenset({'e', 'le', 'se'}): 20,
#  frozenset({'a', 'e', 'le', 'se'}): 20,
#  frozenset({'a', 'le', 'se'}): 21,
#  frozenset({'i', 'se'}): 20,
#  frozenset({'i', 'sa', 'se'}): 20,
#  frozenset({'i', 'la', 'sa', 'se'}): 20,
#  frozenset({'a', 'i', 'la', 'sa', 'se'}): 20,
#  frozenset({'a', 'i', 'sa', 'se'}): 20,
#  frozenset({'i', 'la', 'se'}): 20,
#  frozenset({'a', 'i', 'la', 'se'}): 20,
#  frozenset({'a', 'i', 'se'}): 20,
#  frozenset({'l', 'se'}): 20,
#  frozenset({'l', 'sa', 'se'}): 20,
#  frozenset({'l', 'la', 'sa', 'se'}): 20,
#  frozenset({'a', 'l', 'la', 'sa', 'se'}): 20,
#  frozenset({'a', 'l', 'sa', 'se'}): 20,
#  frozenset({'l', 'la', 'se'}): 20,
#  frozenset({'a', 'l', 'la', 'se'}): 20,
#  frozenset({'a', 'l', 'se'}): 20,
#  frozenset({'pa', 'se'}): 20,
#  frozenset({'pa', 'sa', 'se'}): 20,
#  frozenset({'la', 'pa', 'sa', 'se'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'se'}): 20,
#  frozenset({'a', 'pa', 'sa', 'se'}): 20,
#  frozenset({'la', 'pa', 'se'}): 20,
#  frozenset({'a', 'la', 'pa', 'se'}): 20,
#  frozenset({'a', 'pa', 'se'}): 20,
#  frozenset({'sa', 'se'}): 21,
#  frozenset({'la', 'sa', 'se'}): 21,
#  frozenset({'e', 'la', 'sa', 'se'}): 20,
#  frozenset({'a', 'e', 'la', 'sa', 'se'}): 20,
#  frozenset({'a', 'la', 'sa', 'se'}): 21,
#  frozenset({'e', 'sa', 'se'}): 20,
#  frozenset({'a', 'e', 'sa', 'se'}): 20,
#  frozenset({'a', 'sa', 'se'}): 21,
#  frozenset({'la', 'se'}): 22,
#  frozenset({'e', 'la', 'se'}): 21,
#  frozenset({'a', 'e', 'la', 'se'}): 21,
#  frozenset({'a', 'la', 'se'}): 22,
#  frozenset({'e', 'se'}): 21,
#  frozenset({'a', 'e', 'se'}): 21,
#  frozenset({'a', 'se'}): 22,
#  frozenset({'ty'}): 22,
#  frozenset({'ty', 'wi'}): 20,
#  frozenset({'la', 'ty', 'wi'}): 20,
#  frozenset({'e', 'la', 'ty', 'wi'}): 20,
#  frozenset({'a', 'e', 'la', 'ty', 'wi'}): 20,
#  frozenset({'a', 'la', 'ty', 'wi'}): 20,
#  frozenset({'e', 'ty', 'wi'}): 20,
#  frozenset({'a', 'e', 'ty', 'wi'}): 20,
#  frozenset({'a', 'ty', 'wi'}): 20,
#  frozenset({'mwa', 'ty'}): 20,
#  frozenset({'e', 'mwa', 'ty'}): 20,
#  frozenset({'a', 'e', 'mwa', 'ty'}): 20,
#  frozenset({'a', 'mwa', 'ty'}): 20,
#  frozenset({'la', 'ty'}): 20,
#  frozenset({'e', 'la', 'ty'}): 20,
#  frozenset({'a', 'e', 'la', 'ty'}): 20,
#  frozenset({'a', 'la', 'ty'}): 20,
#  frozenset({'e', 'ty'}): 22,
#  frozenset({'a', 'e', 'ty'}): 22,
#  frozenset({'a', 'ty'}): 22,
#  frozenset({'le'}): 23,
#  frozenset({'le', 'lə'}): 20,
#  frozenset({'le', 'lə', 'sa'}): 20,
#  frozenset({'la', 'le', 'lə', 'sa'}): 20,
#  frozenset({'a', 'la', 'le', 'lə', 'sa'}): 20,
#  frozenset({'a', 'le', 'lə', 'sa'}): 20,
#  frozenset({'la', 'le', 'lə'}): 20,
#  frozenset({'a', 'la', 'le', 'lə'}): 20,
#  frozenset({'a', 'le', 'lə'}): 20,
#  frozenset({'le', 'ɔ̃'}): 20,
#  frozenset({'i', 'le', 'ɔ̃'}): 20,
#  frozenset({'i', 'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'i', 'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'i', 'la', 'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'i', 'la', 'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'i', 'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'i', 'la', 'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'i', 'la', 'le', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'le', 'ɔ̃'}): 20,
#  frozenset({'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'le', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'le', 'pa', 'ɔ̃'}): 20,
#  frozenset({'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'le', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'le', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'le', 'ɔ̃'}): 20,
#  frozenset({'a', 'le', 'ɔ̃'}): 20,
#  frozenset({'i', 'le'}): 22,
#  frozenset({'i', 'le', 'pa'}): 21,
#  frozenset({'i', 'le', 'pa', 'sa'}): 21,
#  frozenset({'i', 'la', 'le', 'pa', 'sa'}): 21,
#  frozenset({'e', 'i', 'la', 'le', 'pa', 'sa'}): 20,
#  frozenset({'a', 'e', 'i', 'la', 'le', 'pa', 'sa'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'pa', 'sa'}): 21,
#  frozenset({'e', 'i', 'le', 'pa', 'sa'}): 20,
#  frozenset({'a', 'e', 'i', 'le', 'pa', 'sa'}): 20,
#  frozenset({'a', 'i', 'le', 'pa', 'sa'}): 21,
#  frozenset({'i', 'la', 'le', 'pa'}): 21,
#  frozenset({'e', 'i', 'la', 'le', 'pa'}): 20,
#  frozenset({'a', 'e', 'i', 'la', 'le', 'pa'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'pa'}): 21,
#  frozenset({'e', 'i', 'le', 'pa'}): 20,
#  frozenset({'a', 'e', 'i', 'le', 'pa'}): 20,
#  frozenset({'a', 'i', 'le', 'pa'}): 21,
#  frozenset({'i', 'le', 'sa'}): 22,
#  frozenset({'i', 'le', 'm', 'sa'}): 20,
#  frozenset({'i', 'la', 'le', 'm', 'sa'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'm', 'sa'}): 20,
#  frozenset({'a', 'i', 'le', 'm', 'sa'}): 20,
#  frozenset({'i', 'la', 'le', 'sa'}): 22,
#  frozenset({'e', 'i', 'la', 'le', 'sa'}): 21,
#  frozenset({'a', 'e', 'i', 'la', 'le', 'sa'}): 21,
#  frozenset({'a', 'i', 'la', 'le', 'sa'}): 22,
#  frozenset({'e', 'i', 'le', 'sa'}): 21,
#  frozenset({'a', 'e', 'i', 'le', 'sa'}): 21,
#  frozenset({'a', 'i', 'le', 'sa'}): 22,
#  frozenset({'i', 'le', 'm'}): 20,
#  frozenset({'i', 'la', 'le', 'm'}): 20,
#  frozenset({'a', 'i', 'la', 'le', 'm'}): 20,
#  frozenset({'a', 'i', 'le', 'm'}): 20,
#  frozenset({'i', 'la', 'le'}): 22,
#  frozenset({'e', 'i', 'la', 'le'}): 21,
#  frozenset({'a', 'e', 'i', 'la', 'le'}): 21,
#  frozenset({'a', 'i', 'la', 'le'}): 22,
#  frozenset({'e', 'i', 'le'}): 21,
#  frozenset({'a', 'e', 'i', 'le'}): 21,
#  frozenset({'a', 'i', 'le'}): 22,
#  frozenset({'le', 'mamɑ̃'}): 20,
#  frozenset({'le', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'la', 'le', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'la', 'le', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'le', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'la', 'le', 'mamɑ̃'}): 20,
#  frozenset({'a', 'la', 'le', 'mamɑ̃'}): 20,
#  frozenset({'a', 'le', 'mamɑ̃'}): 20,
#  frozenset({'l', 'le'}): 20,
#  frozenset({'l', 'le', 'sa'}): 20,
#  frozenset({'l', 'la', 'le', 'sa'}): 20,
#  frozenset({'a', 'l', 'la', 'le', 'sa'}): 20,
#  frozenset({'a', 'l', 'le', 'sa'}): 20,
#  frozenset({'l', 'la', 'le'}): 20,
#  frozenset({'a', 'l', 'la', 'le'}): 20,
#  frozenset({'a', 'l', 'le'}): 20,
#  frozenset({'le', 'pa'}): 22,
#  frozenset({'le', 'pa', 'sa'}): 22,
#  frozenset({'la', 'le', 'pa', 'sa'}): 22,
#  frozenset({'e', 'la', 'le', 'pa', 'sa'}): 21,
#  frozenset({'a', 'e', 'la', 'le', 'pa', 'sa'}): 21,
#  frozenset({'a', 'la', 'le', 'pa', 'sa'}): 22,
#  frozenset({'e', 'le', 'pa', 'sa'}): 21,
#  frozenset({'a', 'e', 'le', 'pa', 'sa'}): 21,
#  frozenset({'a', 'le', 'pa', 'sa'}): 22,
#  frozenset({'la', 'le', 'pa'}): 22,
#  frozenset({'e', 'la', 'le', 'pa'}): 21,
#  frozenset({'a', 'e', 'la', 'le', 'pa'}): 21,
#  frozenset({'a', 'la', 'le', 'pa'}): 22,
#  frozenset({'e', 'le', 'pa'}): 21,
#  frozenset({'a', 'e', 'le', 'pa'}): 21,
#  frozenset({'a', 'le', 'pa'}): 22,
#  frozenset({'le', 'sa'}): 23,
#  frozenset({'le', 'sa', 'ɛ'}): 20,
#  frozenset({'la', 'le', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'la', 'le', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'le', 'sa', 'ɛ'}): 20,
#  frozenset({'le', 'm', 'sa'}): 20,
#  frozenset({'la', 'le', 'm', 'sa'}): 20,
#  frozenset({'a', 'la', 'le', 'm', 'sa'}): 20,
#  frozenset({'a', 'le', 'm', 'sa'}): 20,
#  frozenset({'la', 'le', 'sa'}): 23,
#  frozenset({'e', 'la', 'le', 'sa'}): 22,
#  frozenset({'a', 'e', 'la', 'le', 'sa'}): 22,
#  frozenset({'a', 'la', 'le', 'sa'}): 23,
#  frozenset({'e', 'le', 'sa'}): 22,
#  frozenset({'a', 'e', 'le', 'sa'}): 22,
#  frozenset({'a', 'le', 'sa'}): 23,
#  frozenset({'le', 'ɛ'}): 20,
#  frozenset({'la', 'le', 'ɛ'}): 20,
#  frozenset({'a', 'la', 'le', 'ɛ'}): 20,
#  frozenset({'a', 'le', 'ɛ'}): 20,
#  frozenset({'le', 'm'}): 20,
#  frozenset({'la', 'le', 'm'}): 20,
#  frozenset({'a', 'la', 'le', 'm'}): 20,
#  frozenset({'a', 'le', 'm'}): 20,
#  frozenset({'la', 'le'}): 23,
#  frozenset({'e', 'la', 'le'}): 22,
#  frozenset({'a', 'e', 'la', 'le'}): 22,
#  frozenset({'a', 'la', 'le'}): 23,
#  frozenset({'e', 'le'}): 22,
#  frozenset({'a', 'e', 'le'}): 22,
#  frozenset({'a', 'le'}): 23,
#  frozenset({'lə'}): 23,
#  frozenset({'i', 'lə'}): 20,
#  frozenset({'i', 'lə', 'sa'}): 20,
#  frozenset({'i', 'la', 'lə', 'sa'}): 20,
#  frozenset({'a', 'i', 'la', 'lə', 'sa'}): 20,
#  frozenset({'a', 'i', 'lə', 'sa'}): 20,
#  frozenset({'i', 'la', 'lə'}): 20,
#  frozenset({'a', 'i', 'la', 'lə'}): 20,
#  frozenset({'a', 'i', 'lə'}): 20,
#  frozenset({'lə', 'mamɑ̃'}): 20,
#  frozenset({'a', 'lə', 'mamɑ̃'}): 20,
#  frozenset({'l', 'lə'}): 21,
#  frozenset({'a', 'l', 'lə'}): 21,
#  frozenset({'lə', 'pa'}): 20,
#  frozenset({'lə', 'pa', 'sa'}): 20,
#  frozenset({'la', 'lə', 'pa', 'sa'}): 20,
#  frozenset({'a', 'la', 'lə', 'pa', 'sa'}): 20,
#  frozenset({'a', 'lə', 'pa', 'sa'}): 20,
#  frozenset({'la', 'lə', 'pa'}): 20,
#  frozenset({'a', 'la', 'lə', 'pa'}): 20,
#  frozenset({'a', 'lə', 'pa'}): 20,
#  frozenset({'lə', 'sa'}): 21,
#  frozenset({'la', 'lə', 'sa'}): 21,
#  frozenset({'e', 'la', 'lə', 'sa'}): 20,
#  frozenset({'a', 'e', 'la', 'lə', 'sa'}): 20,
#  frozenset({'a', 'la', 'lə', 'sa'}): 21,
#  frozenset({'e', 'lə', 'sa'}): 20,
#  frozenset({'a', 'e', 'lə', 'sa'}): 20,
#  frozenset({'a', 'lə', 'sa'}): 21,
#  frozenset({'la', 'lə'}): 21,
#  frozenset({'e', 'la', 'lə'}): 20,
#  frozenset({'a', 'e', 'la', 'lə'}): 20,
#  frozenset({'a', 'la', 'lə'}): 21,
#  frozenset({'e', 'lə'}): 21,
#  frozenset({'a', 'e', 'lə'}): 21,
#  frozenset({'a', 'lə'}): 23,
#  frozenset({'wi'}): 23,
#  frozenset({'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'pa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'sa', 'wi', 'ɔ̃'}): 20,
#  frozenset({'la', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'wi', 'ɔ̃'}): 20,
#  frozenset({'a', 'wi', 'ɔ̃'}): 20,
#  frozenset({'i', 'wi'}): 20,
#  frozenset({'i', 'pa', 'wi'}): 20,
#  frozenset({'i', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'i', 'la', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'i', 'la', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'i', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'i', 'la', 'pa', 'wi'}): 20,
#  frozenset({'a', 'i', 'la', 'pa', 'wi'}): 20,
#  frozenset({'a', 'i', 'pa', 'wi'}): 20,
#  frozenset({'i', 'sa', 'wi'}): 20,
#  frozenset({'i', 'la', 'sa', 'wi'}): 20,
#  frozenset({'a', 'i', 'la', 'sa', 'wi'}): 20,
#  frozenset({'a', 'i', 'sa', 'wi'}): 20,
#  frozenset({'i', 'la', 'wi'}): 20,
#  frozenset({'a', 'i', 'la', 'wi'}): 20,
#  frozenset({'a', 'i', 'wi'}): 20,
#  frozenset({'mwa', 'wi'}): 21,
#  frozenset({'mwa', 'pa', 'wi'}): 20,
#  frozenset({'mwa', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'wi'}): 20,
#  frozenset({'mwa', 'sa', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'sa', 'wi'}): 20,
#  frozenset({'la', 'mwa', 'wi'}): 21,
#  frozenset({'e', 'la', 'mwa', 'wi'}): 20,
#  frozenset({'a', 'e', 'la', 'mwa', 'wi'}): 20,
#  frozenset({'a', 'la', 'mwa', 'wi'}): 21,
#  frozenset({'e', 'mwa', 'wi'}): 20,
#  frozenset({'a', 'e', 'mwa', 'wi'}): 20,
#  frozenset({'a', 'mwa', 'wi'}): 21,
#  frozenset({'pa', 'wi'}): 21,
#  frozenset({'pa', 'sa', 'wi'}): 21,
#  frozenset({'la', 'pa', 'sa', 'wi'}): 21,
#  frozenset({'e', 'la', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'e', 'la', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'wi'}): 21,
#  frozenset({'e', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'e', 'pa', 'sa', 'wi'}): 20,
#  frozenset({'a', 'pa', 'sa', 'wi'}): 21,
#  frozenset({'la', 'pa', 'wi'}): 21,
#  frozenset({'e', 'la', 'pa', 'wi'}): 20,
#  frozenset({'a', 'e', 'la', 'pa', 'wi'}): 20,
#  frozenset({'a', 'la', 'pa', 'wi'}): 21,
#  frozenset({'e', 'pa', 'wi'}): 20,
#  frozenset({'a', 'e', 'pa', 'wi'}): 20,
#  frozenset({'a', 'pa', 'wi'}): 21,
#  frozenset({'sa', 'wi'}): 21,
#  frozenset({'la', 'sa', 'wi'}): 21,
#  frozenset({'e', 'la', 'sa', 'wi'}): 20,
#  frozenset({'a', 'e', 'la', 'sa', 'wi'}): 20,
#  frozenset({'a', 'la', 'sa', 'wi'}): 21,
#  frozenset({'e', 'sa', 'wi'}): 20,
#  frozenset({'a', 'e', 'sa', 'wi'}): 20,
#  frozenset({'a', 'sa', 'wi'}): 21,
#  frozenset({'m', 'wi'}): 20,
#  frozenset({'la', 'm', 'wi'}): 20,
#  frozenset({'a', 'la', 'm', 'wi'}): 20,
#  frozenset({'a', 'm', 'wi'}): 20,
#  frozenset({'la', 'wi'}): 23,
#  frozenset({'e', 'la', 'wi'}): 22,
#  frozenset({'a', 'e', 'la', 'wi'}): 22,
#  frozenset({'a', 'la', 'wi'}): 23,
#  frozenset({'e', 'wi'}): 22,
#  frozenset({'a', 'e', 'wi'}): 22,
#  frozenset({'a', 'wi'}): 23,
#  frozenset({'ɔ̃'}): 23,
#  frozenset({'i', 'ɔ̃'}): 21,
#  frozenset({'i', 'pa', 'ɔ̃'}): 21,
#  frozenset({'i', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'i', 'la', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'la', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'la', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'i', 'la', 'pa', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'la', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'la', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'pa', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'pa', 'ɔ̃'}): 21,
#  frozenset({'i', 'sa', 'ɔ̃'}): 21,
#  frozenset({'i', 'la', 'sa', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'la', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'la', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'sa', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'sa', 'ɔ̃'}): 21,
#  frozenset({'i', 'la', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'la', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'la', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'ɔ̃'}): 21,
#  frozenset({'e', 'i', 'ɔ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'ɔ̃'}): 20,
#  frozenset({'a', 'i', 'ɔ̃'}): 21,
#  frozenset({'mwa', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'ɔ̃'}): 20,
#  frozenset({'mwa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'sa', 'ɔ̃'}): 20,
#  frozenset({'la', 'mwa', 'ɔ̃'}): 20,
#  frozenset({'a', 'la', 'mwa', 'ɔ̃'}): 20,
#  frozenset({'a', 'mwa', 'ɔ̃'}): 20,
#  frozenset({'pa', 'ɔ̃'}): 23,
#  frozenset({'pa', 'sa', 'ɔ̃'}): 22,
#  frozenset({'la', 'pa', 'sa', 'ɔ̃'}): 22,
#  frozenset({'e', 'la', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'la', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'la', 'pa', 'sa', 'ɔ̃'}): 22,
#  frozenset({'e', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'pa', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'pa', 'sa', 'ɔ̃'}): 22,
#  frozenset({'la', 'pa', 'ɔ̃'}): 23,
#  frozenset({'e', 'la', 'pa', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'la', 'pa', 'ɔ̃'}): 21,
#  frozenset({'a', 'la', 'pa', 'ɔ̃'}): 23,
#  frozenset({'e', 'pa', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'pa', 'ɔ̃'}): 21,
#  frozenset({'a', 'pa', 'ɔ̃'}): 23,
#  frozenset({'sa', 'ɔ̃'}): 22,
#  frozenset({'la', 'sa', 'ɔ̃'}): 22,
#  frozenset({'e', 'la', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'la', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'la', 'sa', 'ɔ̃'}): 22,
#  frozenset({'e', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'sa', 'ɔ̃'}): 21,
#  frozenset({'a', 'sa', 'ɔ̃'}): 22,
#  frozenset({'la', 'ɔ̃'}): 23,
#  frozenset({'e', 'la', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'la', 'ɔ̃'}): 21,
#  frozenset({'a', 'la', 'ɔ̃'}): 23,
#  frozenset({'e', 'ɔ̃'}): 21,
#  frozenset({'a', 'e', 'ɔ̃'}): 21,
#  frozenset({'a', 'ɔ̃'}): 23,
#  frozenset({'i'}): 24,
#  frozenset({'i', 'mamɑ̃'}): 21,
#  frozenset({'i', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'i', 'la', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'i', 'la', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'i', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'i', 'la', 'mamɑ̃'}): 20,
#  frozenset({'a', 'i', 'la', 'mamɑ̃'}): 20,
#  frozenset({'e', 'i', 'mamɑ̃'}): 20,
#  frozenset({'a', 'e', 'i', 'mamɑ̃'}): 20,
#  frozenset({'a', 'i', 'mamɑ̃'}): 21,
#  frozenset({'i', 'mwa'}): 20,
#  frozenset({'a', 'i', 'mwa'}): 20,
#  frozenset({'i', 'l'}): 20,
#  frozenset({'i', 'l', 'sa'}): 20,
#  frozenset({'i', 'l', 'la', 'sa'}): 20,
#  frozenset({'a', 'i', 'l', 'la', 'sa'}): 20,
#  frozenset({'a', 'i', 'l', 'sa'}): 20,
#  frozenset({'i', 'l', 'la'}): 20,
#  frozenset({'a', 'i', 'l', 'la'}): 20,
#  frozenset({'a', 'i', 'l'}): 20,
#  frozenset({'i', 'pa'}): 22,
#  frozenset({'i', 'pa', 'sa'}): 22,
#  frozenset({'i', 'la', 'pa', 'sa'}): 22,
#  frozenset({'e', 'i', 'la', 'pa', 'sa'}): 21,
#  frozenset({'a', 'e', 'i', 'la', 'pa', 'sa'}): 21,
#  frozenset({'a', 'i', 'la', 'pa', 'sa'}): 22,
#  frozenset({'e', 'i', 'pa', 'sa'}): 21,
#  frozenset({'a', 'e', 'i', 'pa', 'sa'}): 21,
#  frozenset({'a', 'i', 'pa', 'sa'}): 22,
#  frozenset({'i', 'la', 'pa'}): 22,
#  frozenset({'e', 'i', 'la', 'pa'}): 21,
#  frozenset({'a', 'e', 'i', 'la', 'pa'}): 21,
#  frozenset({'a', 'i', 'la', 'pa'}): 22,
#  frozenset({'e', 'i', 'pa'}): 21,
#  frozenset({'a', 'e', 'i', 'pa'}): 21,
#  frozenset({'a', 'i', 'pa'}): 22,
#  frozenset({'i', 'sa'}): 23,
#  frozenset({'i', 'sa', 'ɛ'}): 20,
#  frozenset({'i', 'la', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'i', 'la', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'i', 'sa', 'ɛ'}): 20,
#  frozenset({'i', 'm', 'sa'}): 20,
#  frozenset({'i', 'la', 'm', 'sa'}): 20,
#  frozenset({'a', 'i', 'la', 'm', 'sa'}): 20,
#  frozenset({'a', 'i', 'm', 'sa'}): 20,
#  frozenset({'i', 'la', 'sa'}): 23,
#  frozenset({'e', 'i', 'la', 'sa'}): 22,
#  frozenset({'a', 'e', 'i', 'la', 'sa'}): 22,
#  frozenset({'a', 'i', 'la', 'sa'}): 23,
#  frozenset({'e', 'i', 'sa'}): 22,
#  frozenset({'a', 'e', 'i', 'sa'}): 22,
#  frozenset({'a', 'i', 'sa'}): 23,
#  frozenset({'i', 'ɛ'}): 20,
#  frozenset({'i', 'la', 'ɛ'}): 20,
#  frozenset({'a', 'i', 'la', 'ɛ'}): 20,
#  frozenset({'a', 'i', 'ɛ'}): 20,
#  frozenset({'i', 'm'}): 21,
#  frozenset({'i', 'la', 'm'}): 20,
#  frozenset({'a', 'i', 'la', 'm'}): 20,
#  frozenset({'e', 'i', 'm'}): 20,
#  frozenset({'a', 'e', 'i', 'm'}): 20,
#  frozenset({'a', 'i', 'm'}): 21,
#  frozenset({'i', 'la'}): 23,
#  frozenset({'e', 'i', 'la'}): 22,
#  frozenset({'a', 'e', 'i', 'la'}): 22,
#  frozenset({'a', 'i', 'la'}): 23,
#  frozenset({'e', 'i'}): 23,
#  frozenset({'a', 'e', 'i'}): 23,
#  frozenset({'a', 'i'}): 24,
#  frozenset({'mamɑ̃'}): 24,
#  frozenset({'mamɑ̃', 'mwa'}): 21,
#  frozenset({'a', 'mamɑ̃', 'mwa'}): 21,
#  frozenset({'l', 'mamɑ̃'}): 20,
#  frozenset({'a', 'l', 'mamɑ̃'}): 20,
#  frozenset({'mamɑ̃', 'pa'}): 20,
#  frozenset({'mamɑ̃', 'pa', 'sa'}): 20,
#  frozenset({'la', 'mamɑ̃', 'pa', 'sa'}): 20,
#  frozenset({'a', 'la', 'mamɑ̃', 'pa', 'sa'}): 20,
#  frozenset({'a', 'mamɑ̃', 'pa', 'sa'}): 20,
#  frozenset({'la', 'mamɑ̃', 'pa'}): 20,
#  frozenset({'a', 'la', 'mamɑ̃', 'pa'}): 20,
#  frozenset({'a', 'mamɑ̃', 'pa'}): 20,
#  frozenset({'mamɑ̃', 'sa'}): 21,
#  frozenset({'la', 'mamɑ̃', 'sa'}): 21,
#  frozenset({'e', 'la', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'e', 'la', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'la', 'mamɑ̃', 'sa'}): 21,
#  frozenset({'e', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'e', 'mamɑ̃', 'sa'}): 20,
#  frozenset({'a', 'mamɑ̃', 'sa'}): 21,
#  frozenset({'mamɑ̃', 'ɛ'}): 20,
#  frozenset({'la', 'mamɑ̃', 'ɛ'}): 20,
#  frozenset({'a', 'la', 'mamɑ̃', 'ɛ'}): 20,
#  frozenset({'a', 'mamɑ̃', 'ɛ'}): 20,
#  frozenset({'la', 'mamɑ̃'}): 22,
#  frozenset({'e', 'la', 'mamɑ̃'}): 21,
#  frozenset({'a', 'e', 'la', 'mamɑ̃'}): 21,
#  frozenset({'a', 'la', 'mamɑ̃'}): 22,
#  frozenset({'e', 'mamɑ̃'}): 22,
#  frozenset({'a', 'e', 'mamɑ̃'}): 22,
#  frozenset({'a', 'mamɑ̃'}): 24,
#  frozenset({'mwa'}): 24,
#  frozenset({'l', 'mwa'}): 20,
#  frozenset({'a', 'l', 'mwa'}): 20,
#  frozenset({'mwa', 'pa'}): 21,
#  frozenset({'mwa', 'pa', 'sa'}): 21,
#  frozenset({'la', 'mwa', 'pa', 'sa'}): 21,
#  frozenset({'e', 'la', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'a', 'e', 'la', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa', 'sa'}): 21,
#  frozenset({'e', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'a', 'e', 'mwa', 'pa', 'sa'}): 20,
#  frozenset({'a', 'mwa', 'pa', 'sa'}): 21,
#  frozenset({'la', 'mwa', 'pa'}): 21,
#  frozenset({'e', 'la', 'mwa', 'pa'}): 20,
#  frozenset({'a', 'e', 'la', 'mwa', 'pa'}): 20,
#  frozenset({'a', 'la', 'mwa', 'pa'}): 21,
#  frozenset({'e', 'mwa', 'pa'}): 20,
#  frozenset({'a', 'e', 'mwa', 'pa'}): 20,
#  frozenset({'a', 'mwa', 'pa'}): 21,
#  frozenset({'mwa', 'sa'}): 21,
#  frozenset({'la', 'mwa', 'sa'}): 21,
#  frozenset({'e', 'la', 'mwa', 'sa'}): 20,
#  frozenset({'a', 'e', 'la', 'mwa', 'sa'}): 20,
#  frozenset({'a', 'la', 'mwa', 'sa'}): 21,
#  frozenset({'e', 'mwa', 'sa'}): 20,
#  frozenset({'a', 'e', 'mwa', 'sa'}): 20,
#  frozenset({'a', 'mwa', 'sa'}): 21,
#  frozenset({'la', 'mwa'}): 22,
#  frozenset({'e', 'la', 'mwa'}): 21,
#  frozenset({'a', 'e', 'la', 'mwa'}): 21,
#  frozenset({'a', 'la', 'mwa'}): 22,
#  frozenset({'e', 'mwa'}): 22,
#  frozenset({'a', 'e', 'mwa'}): 22,
#  frozenset({'a', 'mwa'}): 24,
#  frozenset({'l'}): 25,
#  frozenset({'l', 'pa'}): 20,
#  frozenset({'l', 'pa', 'sa'}): 20,
#  frozenset({'l', 'la', 'pa', 'sa'}): 20,
#  frozenset({'a', 'l', 'la', 'pa', 'sa'}): 20,
#  frozenset({'a', 'l', 'pa', 'sa'}): 20,
#  frozenset({'l', 'la', 'pa'}): 20,
#  frozenset({'a', 'l', 'la', 'pa'}): 20,
#  frozenset({'a', 'l', 'pa'}): 20,
#  frozenset({'l', 'sa'}): 21,
#  frozenset({'l', 'la', 'sa'}): 21,
#  frozenset({'e', 'l', 'la', 'sa'}): 20,
#  frozenset({'a', 'e', 'l', 'la', 'sa'}): 20,
#  frozenset({'a', 'l', 'la', 'sa'}): 21,
#  frozenset({'e', 'l', 'sa'}): 20,
#  frozenset({'a', 'e', 'l', 'sa'}): 20,
#  frozenset({'a', 'l', 'sa'}): 21,
#  frozenset({'l', 'la'}): 22,
#  frozenset({'e', 'l', 'la'}): 21,
#  frozenset({'a', 'e', 'l', 'la'}): 21,
#  frozenset({'a', 'l', 'la'}): 22,
#  frozenset({'e', 'l'}): 23,
#  frozenset({'a', 'e', 'l'}): 23,
#  frozenset({'a', 'l'}): 25,
#  frozenset({'pa'}): 25,
#  frozenset({'pa', 'sa'}): 24,
#  frozenset({'pa', 'sa', 'ɛ'}): 21,
#  frozenset({'la', 'pa', 'sa', 'ɛ'}): 21,
#  frozenset({'e', 'la', 'pa', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'e', 'la', 'pa', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'la', 'pa', 'sa', 'ɛ'}): 21,
#  frozenset({'e', 'pa', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'e', 'pa', 'sa', 'ɛ'}): 20,
#  frozenset({'a', 'pa', 'sa', 'ɛ'}): 21,
#  frozenset({'m', 'pa', 'sa'}): 20,
#  frozenset({'la', 'm', 'pa', 'sa'}): 20,
#  frozenset({'a', 'la', 'm', 'pa', 'sa'}): 20,
#  frozenset({'a', 'm', 'pa', 'sa'}): 20,
#  frozenset({'la', 'pa', 'sa'}): 24,
#  frozenset({'e', 'la', 'pa', 'sa'}): 23,
#  frozenset({'a', 'e', 'la', 'pa', 'sa'}): 23,
#  frozenset({'a', 'la', 'pa', 'sa'}): 24,
#  frozenset({'e', 'pa', 'sa'}): 23,
#  frozenset({'a', 'e', 'pa', 'sa'}): 23,
#  frozenset({'a', 'pa', 'sa'}): 24,
#  frozenset({'pa', 'ɛ'}): 21,
#  frozenset({'la', 'pa', 'ɛ'}): 21,
#  frozenset({'e', 'la', 'pa', 'ɛ'}): 20,
#  frozenset({'a', 'e', 'la', 'pa', 'ɛ'}): 20,
#  frozenset({'a', 'la', 'pa', 'ɛ'}): 21,
#  frozenset({'e', 'pa', 'ɛ'}): 20,
#  frozenset({'a', 'e', 'pa', 'ɛ'}): 20,
#  frozenset({'a', 'pa', 'ɛ'}): 21,
#  frozenset({'m', 'pa'}): 20,
#  frozenset({'la', 'm', 'pa'}): 20,
#  frozenset({'a', 'la', 'm', 'pa'}): 20,
#  frozenset({'a', 'm', 'pa'}): 20,
#  frozenset({'la', 'pa'}): 25,
#  frozenset({'e', 'la', 'pa'}): 23,
#  frozenset({'a', 'e', 'la', 'pa'}): 23,
#  frozenset({'a', 'la', 'pa'}): 25,
#  frozenset({'e', 'pa'}): 23,
#  frozenset({'a', 'e', 'pa'}): 23,
#  frozenset({'a', 'pa'}): 25,
#  frozenset({'sa'}): 25,
#  frozenset({'sa', 'ɛ'}): 22,
#  frozenset({'la', 'sa', 'ɛ'}): 22,
#  frozenset({'e', 'la', 'sa', 'ɛ'}): 21,
#  frozenset({'a', 'e', 'la', 'sa', 'ɛ'}): 21,
#  frozenset({'a', 'la', 'sa', 'ɛ'}): 22,
#  frozenset({'e', 'sa', 'ɛ'}): 21,
#  ...}

# %%
rules = assocrules.mine_assoc_rules(item_sets, min_support=min_supp, min_confidence=0.5)
rules
# Out:
# [(frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'ɔ̃'}),
#   frozenset({'a', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa'}),
#   frozenset({'a', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa'}),
#   frozenset({'a', 'la', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'mwa'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'la', 'mwa'}),
#   frozenset({'a', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'la'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.6896551724137931),
#  (frozenset({'la', 'pa'}),
#   frozenset({'a', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'la', 'mwa', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'pa', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'pa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'mwa', 'pa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'wi'}),
#   frozenset({'a', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'wi'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'wi'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'wi'}),
#   frozenset({'a', 'sa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'wi'}),
#   frozenset({'a', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa', 'wi'}),
#   frozenset({'a', 'la', 'sa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va'}),
#   frozenset({'a', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'va'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'va'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'va', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va'}),
#   frozenset({'a', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va'}),
#   frozenset({'a', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va'}),
#   frozenset({'a', 'la', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va', 'wi'}),
#   frozenset({'a', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'va', 'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'va', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va', 'wi'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'wi'}),
#   frozenset({'a', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va', 'wi'}),
#   frozenset({'a', 'mwa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va', 'wi'}),
#   frozenset({'a', 'la', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'ɔ̃'}),
#   frozenset({'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'ɔ̃'}),
#   frozenset({'pa', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa'}),
#   frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'mwa'}),
#   frozenset({'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.6060606060606061),
#  (frozenset({'a', 'la'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.6896551724137931),
#  (frozenset({'a', 'la', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'mwa', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa'}),
#   frozenset({'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'pa'}),
#   frozenset({'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'a', 'pa'}),
#   frozenset({'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'a', 'mwa', 'pa'}),
#   frozenset({'la', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'pa', 'ɔ̃'}),
#   frozenset({'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'pa', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'mwa', 'pa', 'ɔ̃'}),
#   frozenset({'la', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'wi', 'ɔ̃'}),
#   frozenset({'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'wi'}),
#   frozenset({'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'wi'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'mwa', 'wi'}),
#   frozenset({'la', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'wi'}),
#   frozenset({'sa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'wi'}),
#   frozenset({'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'wi'}),
#   frozenset({'la', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'pa', 'wi'}),
#   frozenset({'la', 'sa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'va', 'ɔ̃'}),
#   frozenset({'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'va'}),
#   frozenset({'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'va'}),
#   frozenset({'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'va'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'va'}),
#   frozenset({'la', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'va'}),
#   frozenset({'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'va'}),
#   frozenset({'mwa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'va'}),
#   frozenset({'la', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va'}),
#   frozenset({'la', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'va', 'wi'}),
#   frozenset({'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'va', 'wi'}),
#   frozenset({'mwa', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'va', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'va', 'wi'}),
#   frozenset({'la', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va', 'wi'}),
#   frozenset({'la', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'va', 'wi'}),
#   frozenset({'la', 'mwa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi'}),
#   frozenset({'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'va', 'wi'}),
#   frozenset({'mwa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa'}),
#   frozenset({'a', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'mwa', 'sa'}),
#   frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa'}),
#   frozenset({'a', 'la', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'la', 'sa'}),
#   frozenset({'a', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'la', 'pa', 'sa'}),
#   frozenset({'a', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'pa', 'sa'}),
#   frozenset({'a', 'la', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'mwa', 'pa', 'sa'}),
#   frozenset({'a', 'la', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'mwa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'sa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'mwa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'pa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'mwa', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'wi'}),
#   frozenset({'a', 'pa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa', 'wi'}),
#   frozenset({'a', 'la', 'pa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'wi'}),
#   frozenset({'a', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'wi'}),
#   frozenset({'a', 'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'sa', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa', 'sa', 'wi'}),
#   frozenset({'a', 'la', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va'}),
#   frozenset({'a', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va'}),
#   frozenset({'a', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'va'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa', 'va'}),
#   frozenset({'a', 'la', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va'}),
#   frozenset({'a', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va'}),
#   frozenset({'a', 'mwa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va'}),
#   frozenset({'a', 'la', 'mwa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va'}),
#   frozenset({'a', 'la', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'a', 'la', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va', 'wi'}),
#   frozenset({'a', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va', 'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'va', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'va', 'wi'}),
#   frozenset({'a', 'la', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'a', 'la', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'a', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'a', 'mwa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'a', 'mwa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'ɔ̃'}),
#   frozenset({'pa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa'}),
#   frozenset({'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'sa'}),
#   frozenset({'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'a', 'sa'}),
#   frozenset({'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'a', 'mwa', 'sa'}),
#   frozenset({'la', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'sa', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'mwa', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa'}),
#   frozenset({'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'pa', 'sa'}),
#   frozenset({'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a', 'pa', 'sa'}),
#   frozenset({'la', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a', 'mwa', 'pa', 'sa'}),
#   frozenset({'la', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'wi'}),
#   frozenset({'pa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'sa', 'wi'}),
#   frozenset({'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'sa', 'wi'}),
#   frozenset({'la', 'pa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'wi'}),
#   frozenset({'la', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'sa', 'wi'}),
#   frozenset({'la', 'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi'}),
#   frozenset({'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'wi'}),
#   frozenset({'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'va'}),
#   frozenset({'pa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'sa', 'va'}),
#   frozenset({'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'va'}),
#   frozenset({'la', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'sa', 'va'}),
#   frozenset({'la', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'va'}),
#   frozenset({'la', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'sa', 'va'}),
#   frozenset({'la', 'mwa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va'}),
#   frozenset({'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'va'}),
#   frozenset({'mwa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'pa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'sa', 'va', 'wi'}),
#   frozenset({'la', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'sa', 'va', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'va', 'wi'}),
#   frozenset({'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'sa', 'va', 'wi'}),
#   frozenset({'mwa', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'la', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'la', 'mwa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'mwa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'ɔ̃'}),
#   frozenset({'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa'}),
#   frozenset({'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa'}),
#   frozenset({'la', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa'}),
#   frozenset({'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'mwa'}),
#   frozenset({'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'la', 'mwa'}),
#   frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'la'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.6896551724137931),
#  (frozenset({'la', 'pa'}),
#   frozenset({'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'la', 'mwa', 'ɔ̃'}),
#   frozenset({'pa', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'pa', 'ɔ̃'}),
#   frozenset({'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'pa', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'mwa', 'pa', 'ɔ̃'}),
#   frozenset({'la', 'sa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'wi', 'ɔ̃'}),
#   frozenset({'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'wi'}),
#   frozenset({'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'wi'}),
#   frozenset({'la', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'wi'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'wi'}),
#   frozenset({'sa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'wi'}),
#   frozenset({'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'wi'}),
#   frozenset({'la', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa', 'wi'}),
#   frozenset({'la', 'sa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'sa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va', 'ɔ̃'}),
#   frozenset({'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va'}),
#   frozenset({'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va'}),
#   frozenset({'la', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'va'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'va'}),
#   frozenset({'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va'}),
#   frozenset({'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va'}),
#   frozenset({'mwa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va'}),
#   frozenset({'la', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va'}),
#   frozenset({'la', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'sa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'va', 'wi'}),
#   frozenset({'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'va', 'wi'}),
#   frozenset({'mwa', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'va', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va', 'wi'}),
#   frozenset({'la', 'pa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'wi'}),
#   frozenset({'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va', 'wi'}),
#   frozenset({'mwa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va', 'wi'}),
#   frozenset({'la', 'mwa', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va', 'wi'}),
#   frozenset({'la', 'sa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'sa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa'}),
#   frozenset({'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'mwa', 'sa'}),
#   frozenset({'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa'}),
#   frozenset({'la', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa'}),
#   frozenset({'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'la', 'sa'}),
#   frozenset({'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8),
#  (frozenset({'la', 'pa', 'sa'}),
#   frozenset({'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'pa', 'sa'}),
#   frozenset({'la', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'mwa', 'pa', 'sa'}),
#   frozenset({'la', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'mwa', 'sa', 'ɔ̃'}),
#   frozenset({'pa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'sa', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'mwa', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'pa', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'mwa', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'va', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'wi'}),
#   frozenset({'pa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'wi'}),
#   frozenset({'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa', 'wi'}),
#   frozenset({'la', 'pa', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'wi'}),
#   frozenset({'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'wi'}),
#   frozenset({'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'sa', 'wi'}),
#   frozenset({'la', 'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa', 'sa', 'wi'}),
#   frozenset({'la', 'va', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'va'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'va'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va'}),
#   frozenset({'pa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va'}),
#   frozenset({'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'va'}),
#   frozenset({'la', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa', 'va'}),
#   frozenset({'la', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va'}),
#   frozenset({'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va'}),
#   frozenset({'mwa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va'}),
#   frozenset({'la', 'mwa', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va'}),
#   frozenset({'la', 'wi', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'mwa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   frozenset({'la', 'wi'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'pa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va', 'wi'}),
#   frozenset({'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va', 'wi'}),
#   frozenset({'mwa', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'va', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'va', 'wi'}),
#   frozenset({'la', 'pa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'pa'}),
#   20,
#   1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'mwa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi'}),
#   frozenset({'la', 'mwa', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}),
#   frozenset({'la', 'ɔ̃'}),
#   20,
#   1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'mwa'}),
#   20,
#   1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la', 'mwa'}),
#   20,
#   1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   frozenset({'la'}),
#   20,
#   1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}), frozenset({'sa'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'sa'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'wi', 'ɔ̃'}), frozenset({'a', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'ɔ̃'}), frozenset({'a', 'sa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'ɔ̃'}), frozenset({'a', 'pa', 'sa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'mwa'}),
#   frozenset({'a', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'mwa', 'pa'}),
#   frozenset({'a', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa'}), frozenset({'a', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'pa', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'mwa', 'wi', 'ɔ̃'}), frozenset({'a', 'pa', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'wi'}),
#   frozenset({'a', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'wi', 'ɔ̃'}), frozenset({'a', 'mwa', 'pa', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'wi'}), frozenset({'a', 'sa', 'va', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'wi'}),
#   frozenset({'a', 'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'wi', 'ɔ̃'}), frozenset({'a', 'mwa', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'va', 'ɔ̃'}), frozenset({'a', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'va', 'ɔ̃'}), frozenset({'a', 'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'va'}), frozenset({'a', 'pa', 'sa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'va'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'va', 'ɔ̃'}), frozenset({'a', 'mwa', 'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'va'}), frozenset({'a', 'sa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'va'}), frozenset({'a', 'mwa', 'sa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'va', 'ɔ̃'}), frozenset({'a', 'mwa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'mwa', 'va', 'wi'}), frozenset({'a', 'pa', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'va', 'wi'}), frozenset({'a', 'mwa', 'pa', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'va', 'wi', 'ɔ̃'}), frozenset({'a', 'mwa', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'va', 'wi'}), frozenset({'a', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'va', 'wi'}), frozenset({'a', 'mwa', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'mwa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'wi', 'ɔ̃'}), frozenset({'sa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'ɔ̃'}), frozenset({'sa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'ɔ̃'}), frozenset({'pa', 'sa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa'}),
#   frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.6060606060606061),
#  (frozenset({'a', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'mwa', 'pa'}),
#   frozenset({'sa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa'}), frozenset({'mwa', 'sa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'a', 'pa', 'ɔ̃'}),
#   frozenset({'mwa', 'sa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'mwa', 'wi', 'ɔ̃'}), frozenset({'pa', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'wi'}),
#   frozenset({'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'wi'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'wi', 'ɔ̃'}), frozenset({'mwa', 'pa', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'wi'}), frozenset({'sa', 'va', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'wi'}),
#   frozenset({'mwa', 'sa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'wi', 'ɔ̃'}), frozenset({'mwa', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va', 'ɔ̃'}), frozenset({'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'va', 'ɔ̃'}), frozenset({'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'va'}), frozenset({'pa', 'sa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'va'}),
#   frozenset({'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'va', 'ɔ̃'}), frozenset({'mwa', 'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va'}), frozenset({'sa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'va'}), frozenset({'mwa', 'sa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'va', 'ɔ̃'}), frozenset({'mwa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'va', 'wi', 'ɔ̃'}), frozenset({'pa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'va', 'wi'}), frozenset({'pa', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'va', 'wi'}), frozenset({'mwa', 'pa', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'va', 'wi', 'ɔ̃'}), frozenset({'mwa', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va', 'wi'}), frozenset({'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'va', 'wi'}), frozenset({'mwa', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}), frozenset({'mwa', 'sa'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'ɔ̃'}), frozenset({'a', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa'}),
#   frozenset({'a', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa'}),
#   frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa'}), frozenset({'a', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'pa', 'sa'}),
#   frozenset({'a', 'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'mwa', 'sa', 'ɔ̃'}), frozenset({'a', 'pa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'sa', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'pa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'mwa', 'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'sa', 'wi'}), frozenset({'a', 'pa', 'va', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'sa', 'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'mwa', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'wi'}), frozenset({'a', 'va', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'wi'}),
#   frozenset({'a', 'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'mwa', 'va'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'a', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'sa', 'va', 'ɔ̃'}), frozenset({'a', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'sa', 'va'}), frozenset({'a', 'pa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'sa', 'va'}),
#   frozenset({'a', 'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'va', 'ɔ̃'}), frozenset({'a', 'mwa', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va'}), frozenset({'a', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va'}), frozenset({'a', 'mwa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'a', 'mwa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'pa'}), 20, 1.0),
#  (frozenset({'mwa', 'sa', 'va', 'wi'}), frozenset({'a', 'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'sa', 'va', 'wi'}), frozenset({'a', 'mwa', 'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'mwa', 'pa'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}), frozenset({'a', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi'}), frozenset({'a', 'mwa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'mwa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'ɔ̃'}), frozenset({'va', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'sa', 'ɔ̃'}), frozenset({'pa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'sa'}),
#   frozenset({'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa'}), frozenset({'mwa', 'pa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'a', 'sa', 'ɔ̃'}),
#   frozenset({'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'mwa', 'pa', 'sa'}),
#   frozenset({'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'sa'}),
#   frozenset({'mwa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'mwa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'mwa', 'sa', 'wi', 'ɔ̃'}), frozenset({'pa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'sa', 'wi'}), frozenset({'pa', 'va', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'sa', 'wi'}),
#   frozenset({'mwa', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'wi', 'ɔ̃'}), frozenset({'mwa', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'wi'}), frozenset({'va', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'wi'}),
#   frozenset({'mwa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'mwa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'sa', 'va', 'ɔ̃'}), frozenset({'pa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'sa', 'va'}), frozenset({'pa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'sa', 'va'}),
#   frozenset({'mwa', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'va', 'ɔ̃'}), frozenset({'mwa', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'va'}), frozenset({'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va'}), frozenset({'mwa', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'mwa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'pa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'sa', 'va', 'wi'}), frozenset({'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'sa', 'va', 'wi'}), frozenset({'mwa', 'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'mwa', 'pa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi'}), frozenset({'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'wi'}), frozenset({'mwa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'mwa'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}), frozenset({'a'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'wi', 'ɔ̃'}), frozenset({'a', 'va'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'ɔ̃'}), frozenset({'a', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa'}),
#   frozenset({'a', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa'}),
#   frozenset({'a', 'la', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa'}), frozenset({'a', 'la', 'mwa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'mwa'}),
#   frozenset({'a', 'la', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'la', 'mwa'}),
#   frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'la'}),
#   frozenset({'a', 'mwa', 'pa', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.6896551724137931),
#  (frozenset({'la', 'pa'}), frozenset({'a', 'mwa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'la', 'mwa', 'ɔ̃'}), frozenset({'a', 'pa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'ɔ̃'}), frozenset({'a', 'la', 'pa', 'va', 'wi'}), 20, 1.0),
#  (frozenset({'ɔ̃'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'pa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'pa', 'ɔ̃'}),
#   frozenset({'a', 'mwa', 'va', 'wi'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'pa', 'ɔ̃'}),
# ...
#  (frozenset({'a', 'pa', 'va', 'wi'}), frozenset({'la', 'sa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}), frozenset({'la', 'sa'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'va'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'la', 'pa', 'sa'}),
#   frozenset({'a', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'pa', 'sa'}),
#   frozenset({'a', 'la', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'sa'}), frozenset({'a', 'la', 'pa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'la', 'sa'}), frozenset({'a', 'pa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'la', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'sa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'pa', 'sa', 'ɔ̃'}),
#   frozenset({'a', 'la', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'la', 'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'wi'}),
#   frozenset({'a', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'wi'}),
#   frozenset({'a', 'la', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'la', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'wi'}),
#   frozenset({'a', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'sa', 'wi'}),
#   frozenset({'a', 'la', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'a', 'la', 'va'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'a', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'va', 'ɔ̃'}), frozenset({'a', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'va'}),
#   frozenset({'a', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'va'}),
#   frozenset({'a', 'la', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'va', 'ɔ̃'}), frozenset({'a', 'la', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'va'}), frozenset({'a', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va'}), frozenset({'a', 'la', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'a', 'la', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'pa'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'va', 'wi'}), frozenset({'a', 'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'sa', 'va', 'wi'}), frozenset({'a', 'la', 'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'la', 'pa'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'wi'}), frozenset({'a', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi'}), frozenset({'a', 'la', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'a', 'la'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'la', 'sa', 'ɔ̃'}),
#   frozenset({'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'la', 'sa'}), frozenset({'pa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'a', 'sa'}), frozenset({'la', 'pa', 'va', 'wi', 'ɔ̃'}), 20, 0.8),
#  (frozenset({'a', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'pa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'la', 'pa', 'sa'}),
#   frozenset({'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a', 'pa', 'sa'}),
#   frozenset({'la', 'va', 'wi', 'ɔ̃'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a', 'pa', 'sa', 'ɔ̃'}),
#   frozenset({'la', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'la', 'sa', 'wi', 'ɔ̃'}), frozenset({'pa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'sa', 'wi'}),
#   frozenset({'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'wi'}),
#   frozenset({'la', 'pa', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'wi', 'ɔ̃'}), frozenset({'la', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'wi'}),
#   frozenset({'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'sa', 'wi'}),
#   frozenset({'la', 'va', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'sa', 'wi', 'ɔ̃'}), frozenset({'la', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'sa', 'va', 'ɔ̃'}), frozenset({'pa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'sa', 'va'}),
#   frozenset({'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'va'}),
#   frozenset({'la', 'pa', 'wi', 'ɔ̃'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'va', 'ɔ̃'}), frozenset({'la', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'va'}), frozenset({'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va'}), frozenset({'la', 'wi', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'ɔ̃'}), frozenset({'la', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'pa'}), 20, 1.0),
#  (frozenset({'a', 'la', 'sa', 'va', 'wi'}), frozenset({'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'sa', 'va', 'wi'}), frozenset({'la', 'pa', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'la', 'pa'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi'}), frozenset({'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'wi'}), frozenset({'la', 'ɔ̃'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'sa', 'va', 'wi', 'ɔ̃'}), frozenset({'la'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi'}), frozenset({'sa'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va', 'wi'}), frozenset({'a', 'sa'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'wi'}), frozenset({'a', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa'}),
#   frozenset({'a', 'sa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'mwa'}),
#   frozenset({'a', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'mwa'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'la'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.6896551724137931),
#  (frozenset({'mwa', 'pa'}),
#   frozenset({'a', 'la', 'sa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa'}), frozenset({'a', 'la', 'mwa', 'sa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'la', 'pa'}), frozenset({'a', 'mwa', 'sa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'la', 'mwa', 'wi'}),
#   frozenset({'a', 'pa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'wi'}),
#   frozenset({'a', 'la', 'pa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'wi'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'va'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'la', 'pa', 'wi'}),
#   frozenset({'a', 'mwa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa', 'wi'}), frozenset({'a', 'la', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'va'}), frozenset({'a', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'va'}), frozenset({'a', 'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'va'}), frozenset({'a', 'la', 'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'va'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'va'}),
#   frozenset({'a', 'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'pa', 'va'}), frozenset({'a', 'mwa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'pa', 'va'}), frozenset({'a', 'la', 'mwa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'va'}), frozenset({'a', 'la', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'va', 'wi'}), frozenset({'a', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'la', 'va', 'wi'}), frozenset({'a', 'mwa', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'va', 'wi'}), frozenset({'a', 'la', 'mwa', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'mwa', 'va', 'wi'}), frozenset({'a', 'la', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'va', 'wi'}), frozenset({'a', 'mwa', 'sa'}), 20, 1.0),
#  (frozenset({'pa', 'va', 'wi'}), frozenset({'a', 'la', 'mwa', 'sa'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'va', 'wi'}), frozenset({'a', 'la', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'wi'}), frozenset({'sa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa'}),
#   frozenset({'sa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'mwa'}),
#   frozenset({'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.9090909090909091),
#  (frozenset({'a', 'mwa'}),
#   frozenset({'la', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.6060606060606061),
#  (frozenset({'a', 'la'}),
#   frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}),
#   20,
#   0.6896551724137931),
#  (frozenset({'a', 'la', 'pa'}), frozenset({'mwa', 'sa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'a', 'pa'}), frozenset({'la', 'mwa', 'sa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'a', 'mwa', 'pa'}),
#   frozenset({'la', 'sa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'mwa', 'wi'}),
#   frozenset({'pa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'wi'}),
#   frozenset({'mwa', 'pa', 'sa', 'va'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'va'}),
#   20,
#   0.8695652173913043),
#  (frozenset({'a', 'mwa', 'wi'}),
#   frozenset({'la', 'pa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'pa', 'wi'}),
#   frozenset({'mwa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'wi'}),
#   frozenset({'la', 'mwa', 'sa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'pa', 'wi'}), frozenset({'la', 'sa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'va'}), frozenset({'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'va'}), frozenset({'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'va'}),
#   frozenset({'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'va'}),
#   frozenset({'la', 'mwa', 'pa', 'sa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'va'}), frozenset({'la', 'pa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'va'}), frozenset({'mwa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'va'}), frozenset({'la', 'mwa', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va'}), frozenset({'la', 'sa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'va', 'wi'}), frozenset({'pa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'la', 'va', 'wi'}), frozenset({'mwa', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'va', 'wi'}), frozenset({'la', 'mwa', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'va', 'wi'}), frozenset({'la', 'pa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'va', 'wi'}), frozenset({'mwa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'pa', 'va', 'wi'}), frozenset({'la', 'mwa', 'sa'}), 20, 1.0),
#  (frozenset({'a', 'mwa', 'pa', 'va', 'wi'}), frozenset({'la', 'sa'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va', 'wi'}), frozenset({'a'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'wi'}), frozenset({'a', 'va'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa'}),
#   frozenset({'a', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'pa', 'sa'}),
#   frozenset({'a', 'mwa', 'va', 'wi'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'pa', 'sa'}),
#   frozenset({'a', 'la', 'mwa', 'va', 'wi'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'sa'}), frozenset({'a', 'la', 'mwa', 'pa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'la', 'sa'}), frozenset({'a', 'mwa', 'pa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'la', 'mwa', 'sa'}),
#   frozenset({'a', 'pa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa'}),
#   frozenset({'a', 'la', 'pa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa', 'sa'}),
#   frozenset({'a', 'la', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'la', 'mwa', 'sa', 'wi'}), frozenset({'a', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'wi'}),
#   frozenset({'a', 'mwa', 'pa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa', 'wi'}), frozenset({'a', 'la', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'wi'}),
#   frozenset({'a', 'mwa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'pa', 'sa', 'wi'}),
#   frozenset({'a', 'la', 'mwa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'pa', 'sa', 'wi'}), frozenset({'a', 'la', 'va'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'pa', 'sa', 'va'}), frozenset({'a', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va'}), frozenset({'a', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'va'}),
#   frozenset({'a', 'mwa', 'pa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'sa', 'va'}),
#   frozenset({'a', 'la', 'mwa', 'pa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'mwa', 'sa', 'va'}), frozenset({'a', 'la', 'pa', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'va'}), frozenset({'a', 'mwa', 'wi'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va'}), frozenset({'a', 'la', 'mwa', 'wi'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va'}), frozenset({'a', 'la', 'wi'}), 20, 1.0),
#  (frozenset({'la', 'mwa', 'sa', 'va', 'wi'}), frozenset({'a', 'pa'}), 20, 1.0),
#  (frozenset({'la', 'sa', 'va', 'wi'}), frozenset({'a', 'mwa', 'pa'}), 20, 1.0),
#  (frozenset({'sa', 'va', 'wi'}), frozenset({'a', 'la', 'mwa', 'pa'}), 20, 1.0),
#  (frozenset({'mwa', 'sa', 'va', 'wi'}), frozenset({'a', 'la', 'pa'}), 20, 1.0),
#  (frozenset({'la', 'pa', 'sa', 'va', 'wi'}), frozenset({'a', 'mwa'}), 20, 1.0),
#  (frozenset({'pa', 'sa', 'va', 'wi'}), frozenset({'a', 'la', 'mwa'}), 20, 1.0),
#  (frozenset({'mwa', 'pa', 'sa', 'va', 'wi'}), frozenset({'a', 'la'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'wi'}), frozenset({'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa'}),
#   frozenset({'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'mwa', 'sa'}),
#   frozenset({'pa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'sa'}), frozenset({'mwa', 'pa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'a', 'sa'}), frozenset({'la', 'mwa', 'pa', 'va', 'wi'}), 20, 0.8),
#  (frozenset({'a', 'mwa', 'sa'}),
#   frozenset({'la', 'pa', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'pa', 'sa'}),
#   frozenset({'mwa', 'va', 'wi'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a', 'pa', 'sa'}),
#   frozenset({'la', 'mwa', 'va', 'wi'}),
#   20,
#   0.8333333333333334),
#  (frozenset({'a', 'mwa', 'pa', 'sa'}),
#   frozenset({'la', 'va', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'wi'}), frozenset({'pa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'sa', 'wi'}),
#   frozenset({'mwa', 'pa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'wi'}),
#   frozenset({'la', 'mwa', 'pa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'sa', 'wi'}), frozenset({'la', 'pa', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'pa', 'sa', 'wi'}),
#   frozenset({'mwa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'pa', 'sa', 'wi'}),
#   frozenset({'la', 'mwa', 'va'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'pa', 'sa', 'wi'}), frozenset({'la', 'va'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'pa', 'sa', 'va'}), frozenset({'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'mwa', 'sa', 'va'}), frozenset({'pa', 'wi'}), 20, 1.0),
#  (frozenset({'a', 'la', 'sa', 'va'}),
#   frozenset({'mwa', 'pa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'sa', 'va'}),
#   frozenset({'la', 'mwa', 'pa', 'wi'}),
#   20,
#   0.9523809523809523),
#  (frozenset({'a', 'mwa', 'sa', 'va'}), frozenset({'la', 'pa', 'wi'}), 20, 1.0),
#  ...]

# %%
import time

# %%
#seqs = ( 'caabc', 'abcb', 'cabc', 'abbca')
seqs = madeleine_enfant1

freq_seqs = seqmining.freq_seq_enum(seqs, 10)
for seq in freq_seqs:
    print (seq)
